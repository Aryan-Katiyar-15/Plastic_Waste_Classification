# %% [markdown]
# #Dataset Download
# In this section, the dataset is downloaded from Kaggle using kagglehub for the waste classification project. The dataset path is printed for reference.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("techsash/waste-classification-data")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.6), please consider upgrading to the latest version (0.3.7).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/techsash/waste-classification-data?dataset_version_number=1...
# 100%|██████████| 427M/427M [00:04<00:00, 91.1MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/techsash/waste-classification-data/versions/1

# %% [markdown]
# #Defining Dataset Paths

# %%
train_path = "/root/.cache/kagglehub/datasets/techsash/waste-classification-data/versions/1/DATASET/TRAIN"
test_path = "/root/.cache/kagglehub/datasets/techsash/waste-classification-data/versions/1/DATASET/TEST"

# %% [markdown]
# # Importing necessary libraries

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing Libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.utils import plot_model
from glob import glob

# %% [markdown]
# # Image Loading and Data Preparation

# %%
# Visualization
from cv2 import cvtColor
x_data = []
y_data = []
for category in glob(train_path+'/*'):
    for file in tqdm(glob(category+'/*')):
        img_array = cv2.imread(file)
        img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
        x_data.append(img_array)
        y_data.append(category.split('/')[-1])
data = pd.DataFrame({'image':x_data, 'label':y_data})
# Out:
# 100%|██████████| 9999/9999 [00:06<00:00, 1586.99it/s]
# 100%|██████████| 12565/12565 [00:08<00:00, 1529.86it/s]

# %%
data.shape
# Out:
# (22564, 2)

# %% [markdown]
# # Pie chart for label distribution

# %%
colors = ['#a0d157', '#c48bb8']
plt.pie(data.label.value_counts(), labels=['Organic', 'Recyclable'], autopct='%0.2f%%',
        colors=colors, startangle=90, explode=[0.05, 0.05])
plt.show()

# %% [markdown]
# # Displaying some sample images from the dataset

# %%
plt.figure(figsize=(20, 15))
for i in range(9):
    plt.subplot(4, 3,(i%12)+1)
    index = np.random.randint(15000)
    plt.title('This is of {0}'.format(data.label[index]))
    plt.imshow(data.image[index])
    plt.tight_layout()

# %% [markdown]
# #Model Architecture
#
#   Explanation:
#   This section defines the CNN architecture using the Sequential model from Keras. It consists of convolutional layers followed by max-pooling layers, and fully connected layers at the end with dropout for regularization.

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=(224, 224, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(2))
model.add(Activation('sigmoid'))

model.compile(loss = "binary_crossentropy",
              optimizer = "adam",
              metrics = ["accuracy"])
batch_size = 64

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 222, 222, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 109, 109, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 109, 109, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 54, 54, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 52, 52, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 52, 52, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 26, 26, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 86528)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │      22,151,424 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │             130 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 2)                   │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 22,261,250 (84.92 MB)
#  Trainable params: 22,261,250 (84.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Data Augmentation and Image Data Generators
#
#   Data augmentation is applied to the training data using ImageDataGenerator to improve model generalization. We also normalize both the training and testing data using a rescaling factor of 1./255.

# %%
train_datagen = ImageDataGenerator(rescale = 1./255)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size = (224, 224),
    batch_size = batch_size,
    color_mode = "rgb",
    class_mode = "categorical")

test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size = (224, 224),
    batch_size = batch_size,
    color_mode = "rgb",
    class_mode = "categorical")
# Out:
# Found 22564 images belonging to 2 classes.
# Found 2513 images belonging to 2 classes.

# %% [markdown]
# # Early Stopping Implementation
#
#
#   The EarlyStopping callback is added to monitor the validation loss during training. It helps to stop training if the validation loss does not improve for a set number of epochs (patience = 20) and restores the best model weights.

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# %% [markdown]
# # Model Training
#
#
#   The model is trained for 50 epochs using the fit() function, and the early stopping callback is passed to prevent overfitting. The training and validation loss/accuracy can be monitored in real-time.

# %%
hist = model.fit(
    train_generator,
    epochs=50,
    validation_data=test_generator,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 73s 174ms/step - accuracy: 0.7568 - loss: 0.5328 - val_accuracy: 0.8313 - val_loss: 0.3841
# Epoch 2/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 50s 142ms/step - accuracy: 0.8425 - loss: 0.3899 - val_accuracy: 0.8830 - val_loss: 0.3205
# Epoch 3/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 51s 143ms/step - accuracy: 0.8511 - loss: 0.3620 - val_accuracy: 0.9081 - val_loss: 0.2624
# Epoch 4/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 50s 143ms/step - accuracy: 0.8732 - loss: 0.3232 - val_accuracy: 0.9017 - val_loss: 0.2659
# Epoch 5/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 51s 144ms/step - accuracy: 0.8864 - loss: 0.2912 - val_accuracy: 0.9037 - val_loss: 0.2715
# Epoch 6/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 50s 141ms/step - accuracy: 0.9038 - loss: 0.2501 - val_accuracy: 0.9037 - val_loss: 0.2586
# Epoch 7/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 47s 132ms/step - accuracy: 0.9226 - loss: 0.2085 - val_accuracy: 0.8989 - val_loss: 0.2998
# Epoch 8/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 51s 145ms/step - accuracy: 0.9407 - loss: 0.1581 - val_accuracy: 0.8918 - val_loss: 0.3741
# Epoch 9/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 51s 145ms/step - accuracy: 0.9546 - loss: 0.1250 - val_accuracy: 0.8942 - val_loss: 0.3748
# Epoch 10/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 51s 145ms/step - accuracy: 0.9657 - loss: 0.0998 - val_accuracy: 0.8953 - val_loss: 0.4505
# Epoch 11/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 55s 155ms/step - accuracy: 0.9717 - loss: 0.0842 - val_accuracy: 0.8961 - val_loss: 0.5129
# Epoch 12/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 50s 140ms/step - accuracy: 0.9794 - loss: 0.0612 - val_accuracy: 0.8938 - val_loss: 0.4962
# Epoch 13/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 51s 145ms/step - accuracy: 0.9805 - loss: 0.0605 - val_accuracy: 0.8910 - val_loss: 0.4818
# Epoch 14/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 56s 159ms/step - accuracy: 0.9853 - loss: 0.0489 - val_accuracy: 0.8961 - val_loss: 0.5503
# Epoch 15/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 45s 127ms/step - accuracy: 0.9849 - loss: 0.0455 - val_accuracy: 0.9009 - val_loss: 0.5869
# Epoch 16/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 50s 142ms/step - accuracy: 0.9848 - loss: 0.0463 - val_accuracy: 0.9069 - val_loss: 0.5972
# Epoch 17/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 51s 145ms/step - accuracy: 0.9883 - loss: 0.0384 - val_accuracy: 0.9013 - val_loss: 0.6635
# Epoch 18/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 51s 143ms/step - accuracy: 0.9890 - loss: 0.0340 - val_accuracy: 0.8997 - val_loss: 0.7946
# Epoch 19/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 51s 143ms/step - accuracy: 0.9865 - loss: 0.0421 - val_accuracy: 0.9021 - val_loss: 0.5439
# Epoch 20/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 51s 144ms/step - accuracy: 0.9891 - loss: 0.0328 - val_accuracy: 0.9041 - val_loss: 0.7086
# Epoch 21/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 49s 138ms/step - accuracy: 0.9911 - loss: 0.0301 - val_accuracy: 0.8802 - val_loss: 0.9382
# Epoch 22/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 84s 144ms/step - accuracy: 0.9913 - loss: 0.0267 - val_accuracy: 0.8806 - val_loss: 0.9781
# Epoch 23/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 51s 144ms/step - accuracy: 0.9874 - loss: 0.0389 - val_accuracy: 0.8826 - val_loss: 1.1062
# Epoch 24/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 52s 147ms/step - accuracy: 0.9912 - loss: 0.0301 - val_accuracy: 0.8953 - val_loss: 0.7459
# Epoch 25/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 52s 146ms/step - accuracy: 0.9918 - loss: 0.0237 - val_accuracy: 0.9009 - val_loss: 0.7281
# Epoch 26/50
# 353/353 ━━━━━━━━━━━━━━━━━━━━ 80s 139ms/step - accuracy: 0.9930 - loss: 0.0227 - val_accuracy: 0.9037 - val_loss: 0.7591

# %% [markdown]
# #Model Saving
#
#
#   Once training is complete, the trained model is saved to a file to be used later for inference or deployment.

# %%
# Saving the model
model.save("plastic_waste_classifier.h5")
print("Training complete!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Training complete!

# %%
plt.figure(figsize=[10,6])
plt.plot(hist.history["accuracy"], label = "Train acc")
plt.plot(hist.history["val_accuracy"], label = "Validation acc")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(hist.history['loss'], label = "Train loss")
plt.plot(hist.history['val_loss'], label = "Validation loss")
plt.legend()
plt.show()

# %%
def predict_func(img):
    plt.figure(figsize=(6,4))
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.tight_layout()
    img = cv2.resize(img, (224, 224))
    img = np.reshape(img, [-1, 224, 224,3])
    result = np.argmax(model.predict(img))
    if result == 0: print("This image shows recyclable waste")
    elif result ==1: print("This image shows organic waste")

# %%
test_img = cv2.imread("/root/.cache/kagglehub/datasets/techsash/waste-classification-data/versions/1/DATASET/TEST/O/O_12570.jpg")
predict_func(test_img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# This image shows organic waste

# %%
test_img = cv2.imread("/root/.cache/kagglehub/datasets/techsash/waste-classification-data/versions/1/DATASET/TEST/R/R_10752.jpg")
predict_func(test_img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# This image shows organic waste
